# %% [markdown]
# # IV Fluids Level Monitor
#
# This notebook implements a complete workflow to train a convolutional neural network (CNN) for classifying the fill level of IV fluid bottles.

# %%
import os
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image as pil_image
import PIL.ImageOps
import cv2

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, InputLayer
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

print("TensorFlow Version:", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices('GPU'))


ORIGINAL_DATA_PATH = '/kaggle/input/iv-fluids-level-dataset/dataset'
WORKING_DIR = '/kaggle/working/'

IMG_SIZE = 32 
BATCH_SIZE = 32
CLASS_NAMES = ['sal_data_empty', 'sal_data_50', 'sal_data_80', 'sal_data_100']
# Out:
# 2025-12-03 14:05:48.027669: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764770748.255080      20 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764770748.323952      20 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# TensorFlow Version: 2.18.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# ### 2. Generating the Data Label File
#
# As described in the paper and its accompanying `.ipynb` file, the first data handling step is to create a text file that maps every image to its corresponding class label (based on its folder name).
#
# This cell replicates that process by creating `saline_data_label.txt`. This file serves as a manifest for all subsequent preprocessing steps.

# %%
data_label_path = os.path.join(WORKING_DIR, 'data_label')
os.makedirs(data_label_path, exist_ok=True)
label_file_path = os.path.join(data_label_path, 'saline_data_label.txt')

print("Generating label file...")
with open(label_file_path, 'w') as data_file:
    for dir_name in sorted(os.listdir(ORIGINAL_DATA_PATH)): 
        if dir_name in CLASS_NAMES:
            img_path_full = os.path.join(ORIGINAL_DATA_PATH, dir_name)
            for img_name in os.listdir(img_path_full):
                line = f"{dir_name}/{img_name}\n"
                data_file.write(line)
print(f"Label file created at: {label_file_path}")
# Out:
# Generating label file...
# Label file created at: /kaggle/working/data_label/saline_data_label.txt

# %% [markdown]
# ### 3. Preprocessing Pipeline
#
# 1.  **Negative Filter (Invert):** As stated in Section 2.2.1, a negative filter is applied to each image. The authors note this was done "to emphasize the transparency of saline solution's filling level."
# 2.  **Resize:** Each inverted image is resized to **32x32 pixels** to match the required input shape of the model architecture from Fig. 10.
#
# The newly processed images are saved to a separate directory (`processed_images_paper_spec`) to keep the original dataset untouched.

# %%
PROCESSED_DATA_PATH = os.path.join(WORKING_DIR, 'processed_images_paper_spec')
os.makedirs(PROCESSED_DATA_PATH, exist_ok=True)

for name in CLASS_NAMES:
    os.makedirs(os.path.join(PROCESSED_DATA_PATH, name), exist_ok=True)
    
print(f"Starting image preprocessing (Invert + Resize to {IMG_SIZE}x{IMG_SIZE})...")

with open(label_file_path, "r") as f:
    lines = f.readlines()

for line in lines:
    try:
        line = line.strip()
        label, file_name = line.split("/")
        
        original_file_path = os.path.join(ORIGINAL_DATA_PATH, label, file_name)
        img = pil_image.open(original_file_path)

        
        inverted_img = PIL.ImageOps.invert(img) 
        
        
        resized_img = inverted_img.resize((IMG_SIZE, IMG_SIZE), pil_image.LANCZOS)
        
        
        if resized_img.mode != 'RGB':
            resized_img = resized_img.convert('RGB')
            
        
        save_path = os.path.join(PROCESSED_DATA_PATH, label, file_name)
        resized_img.save(save_path)
        
    except Exception as e:
        print(f"Error processing {line}: {e}")

print(f"\nPreprocessing complete.")
# Out:
# Starting image preprocessing (Invert + Resize to 32x32)...
#
# Preprocessing complete.

# %% [markdown]
# ### 4. Creating Data Splits for Robust Training
#
# To properly train and evaluate a machine learning model, the data must be split into three distinct sets:
# - **Training Set (80%):** The data the model learns from.
# - **Validation Set (10%):** Data used after each epoch to check the model's performance on unseen data, guide hyperparameter tuning, and prevent overfitting.
# - **Test Set (10%):** Data held back until the very end. It is used only once to get a final, unbiased assessment of the trained model's real-world performance.
#
# This cell performs an 80/10/10 split on our preprocessed images, ensuring that each set has a proportional representation of all four classes (`stratify`).

# %%
SPLIT_DATA_PATH = os.path.join(WORKING_DIR, 'split_data_paper_spec')

if os.path.exists(SPLIT_DATA_PATH):
    shutil.rmtree(SPLIT_DATA_PATH)

train_dir = os.path.join(SPLIT_DATA_PATH, 'train')
val_dir = os.path.join(SPLIT_DATA_PATH, 'validation')
test_dir = os.path.join(SPLIT_DATA_PATH, 'test')

os.makedirs(train_dir); os.makedirs(val_dir); os.makedirs(test_dir)

all_files = []
for class_name in CLASS_NAMES:
    class_path = os.path.join(PROCESSED_DATA_PATH, class_name)
    os.makedirs(os.path.join(train_dir, class_name)); os.makedirs(os.path.join(val_dir, class_name)); os.makedirs(os.path.join(test_dir, class_name))
    files = os.listdir(class_path)
    for f in files:
        all_files.append((os.path.join(class_path, f), class_name))


train_val_files, test_files = train_test_split(all_files, test_size=0.10, random_state=42, stratify=[label for _, label in all_files])
train_files, val_files = train_test_split(train_val_files, test_size=1/9, random_state=42, stratify=[label for _, label in train_val_files])

def copy_files_to_split(files, dest_base_dir):
    for file_path, class_name in files:
        shutil.copy(file_path, os.path.join(dest_base_dir, class_name))

copy_files_to_split(train_files, train_dir)
copy_files_to_split(val_files, val_dir)
copy_files_to_split(test_files, test_dir)

print("Data splitting complete.")
# Out:
# Data splitting complete.

# %% [markdown]
# ### 5. Preparing the Data Pipeline
#
# This cell sets up the `ImageDataGenerator` to feed data to the model.
#
# **Crucial Step:** A baseline model **"trained without augmentation."**
#
# To faithfully replicate their success, we will also turn off all augmentation for the training set. The only transformation applied by the generator is `rescale=1./255`, which normalizes pixel values from the `[0, 255]` range to the `[0, 1]` range, a standard practice for neural networks.

# %%
print("Creating data generators WITHOUT augmentation to match the paper's benchmark...")

datagen_no_aug = ImageDataGenerator(rescale=1./255)

train_generator = datagen_no_aug.flow_from_directory(
    train_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True 
)

validation_generator = datagen_no_aug.flow_from_directory(
    val_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)

test_generator = datagen_no_aug.flow_from_directory(
    test_dir,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Creating data generators WITHOUT augmentation to match the paper's benchmark...
# Found 3373 images belonging to 4 classes.
# Found 422 images belonging to 4 classes.
# Found 422 images belonging to 4 classes.

# %% [markdown]
# ### 6. Building the CNN Architecture
#
# This cell defines the neural network using the Keras Sequential API.
#
# The model consists of:
# - An input layer expecting `32x32x3` images.
# - Two main convolutional blocks, each containing:
#     - Two `Conv2D` layers for feature extraction.
#     - A `MaxPooling2D` layer to downsample and retain important features.
#     - A `Dropout` layer to prevent overfitting.
# - A classifier head that flattens the feature maps and uses `Dense` layers to make the final prediction via a `softmax` activation function.

# %%
print("Building the exact model architecture from the paper...")
model = Sequential([
    
    InputLayer(input_shape=(IMG_SIZE, IMG_SIZE, 3)),

    
    Conv2D(32, (3, 3), activation='relu', padding='same'),
    Conv2D(32, (3, 3), activation='relu'), 
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    Conv2D(64, (3, 3), activation='relu'), 
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(len(CLASS_NAMES), activation='softmax')
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Building the exact model architecture from the paper...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# I0000 00:00:1764771833.763463      20 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1764771833.764083      20 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 30, 30, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 15, 15, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 15, 15, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 15, 15, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 13, 13, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 6, 6, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 6, 6, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2304)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 4)                   │           2,052 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,247,780 (4.76 MB)
#  Trainable params: 1,247,780 (4.76 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 7. Training the Neural Network
#
# This cell executes the model training process using `model.fit()`.
#
# We are using two important Keras callbacks:
# - **`ModelCheckpoint`**: This will monitor the validation accuracy after each epoch and save the model only when it improves. This ensures that we keep the best version of the model discovered during training.
# - **`EarlyStopping`**: This will monitor the validation loss and stop the training process automatically if the performance does not improve for a set number of epochs (`patience=25`). This prevents overfitting and saves computational time.
#
# We set our maximum epochs to 200, expecting `EarlyStopping` to halt the process within a similar range.

# %%
EPOCHS = 200

early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=25,
    restore_best_weights=True,
    verbose=1
)

model_checkpoint = ModelCheckpoint(
    os.path.join(WORKING_DIR, 'paper_replication_model.h5'), 
    monitor='val_accuracy', 
    save_best_only=True,
    verbose=1
)

history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=validation_generator,
    callbacks=[early_stopping, model_checkpoint]
)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764771838.114963      84 service.cc:148] XLA service 0x792fc800fe80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1764771838.116193      84 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1764771838.116216      84 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1764771838.508208      84 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  17/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2678 - loss: 1.4044
# I0000 00:00:1764771842.623959      84 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 102/106 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.2594 - loss: 1.3923
# Epoch 1: val_accuracy improved from -inf to 0.27725, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - accuracy: 0.2592 - loss: 1.3921 - val_accuracy: 0.2773 - val_loss: 1.3861
# Epoch 2/200
# 101/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2563 - loss: 1.3818
# Epoch 2: val_accuracy improved from 0.27725 to 0.36493, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.2580 - loss: 1.3810 - val_accuracy: 0.3649 - val_loss: 1.3509
# Epoch 3/200
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3836 - loss: 1.2984
# Epoch 3: val_accuracy improved from 0.36493 to 0.40284, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.3837 - loss: 1.2982 - val_accuracy: 0.4028 - val_loss: 1.2574
# Epoch 4/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4306 - loss: 1.2188
# Epoch 4: val_accuracy improved from 0.40284 to 0.56161, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.4315 - loss: 1.2176 - val_accuracy: 0.5616 - val_loss: 1.0610
# Epoch 5/200
# 102/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5585 - loss: 1.0384
# Epoch 5: val_accuracy improved from 0.56161 to 0.67062, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5594 - loss: 1.0371 - val_accuracy: 0.6706 - val_loss: 0.9024
# Epoch 6/200
# 101/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6568 - loss: 0.8473
# Epoch 6: val_accuracy improved from 0.67062 to 0.74882, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6576 - loss: 0.8459 - val_accuracy: 0.7488 - val_loss: 0.6542
# Epoch 7/200
# 101/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7524 - loss: 0.6370
# Epoch 7: val_accuracy improved from 0.74882 to 0.83175, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7530 - loss: 0.6362 - val_accuracy: 0.8318 - val_loss: 0.5199
# Epoch 8/200
# 102/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8240 - loss: 0.4889
# Epoch 8: val_accuracy improved from 0.83175 to 0.84834, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8240 - loss: 0.4888 - val_accuracy: 0.8483 - val_loss: 0.3946
# Epoch 9/200
# 102/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8547 - loss: 0.3796
# Epoch 9: val_accuracy improved from 0.84834 to 0.88626, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8547 - loss: 0.3796 - val_accuracy: 0.8863 - val_loss: 0.3139
# Epoch 10/200
# 105/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8889 - loss: 0.3094
# Epoch 10: val_accuracy did not improve from 0.88626
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8889 - loss: 0.3093 - val_accuracy: 0.8815 - val_loss: 0.3125
# Epoch 11/200
# 103/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9108 - loss: 0.2698
# Epoch 11: val_accuracy improved from 0.88626 to 0.89810, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9108 - loss: 0.2694 - val_accuracy: 0.8981 - val_loss: 0.2777
# Epoch 12/200
# 105/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9240 - loss: 0.1990
# Epoch 12: val_accuracy improved from 0.89810 to 0.90995, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9239 - loss: 0.1991 - val_accuracy: 0.9100 - val_loss: 0.2368
# Epoch 13/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9241 - loss: 0.2030
# Epoch 13: val_accuracy improved from 0.90995 to 0.91232, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9244 - loss: 0.2026 - val_accuracy: 0.9123 - val_loss: 0.2657
# Epoch 14/200
# 103/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9485 - loss: 0.1539
# Epoch 14: val_accuracy improved from 0.91232 to 0.94076, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9484 - loss: 0.1540 - val_accuracy: 0.9408 - val_loss: 0.1800
# Epoch 15/200
# 101/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9510 - loss: 0.1312
# Epoch 15: val_accuracy improved from 0.94076 to 0.95261, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9508 - loss: 0.1317 - val_accuracy: 0.9526 - val_loss: 0.1474
# Epoch 16/200
# 105/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9554 - loss: 0.1255
# Epoch 16: val_accuracy did not improve from 0.95261
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9554 - loss: 0.1254 - val_accuracy: 0.9431 - val_loss: 0.1595
# Epoch 17/200
# 105/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9714 - loss: 0.0865
# Epoch 17: val_accuracy did not improve from 0.95261
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9713 - loss: 0.0868 - val_accuracy: 0.9242 - val_loss: 0.2150
# Epoch 18/200
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9641 - loss: 0.1076
# Epoch 18: val_accuracy did not improve from 0.95261
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9641 - loss: 0.1075 - val_accuracy: 0.9526 - val_loss: 0.1524
# Epoch 19/200
# 105/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9692 - loss: 0.0871
# Epoch 19: val_accuracy did not improve from 0.95261
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9692 - loss: 0.0873 - val_accuracy: 0.9076 - val_loss: 0.2234
# Epoch 20/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9720 - loss: 0.0918
# Epoch 20: val_accuracy improved from 0.95261 to 0.95972, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9721 - loss: 0.0916 - val_accuracy: 0.9597 - val_loss: 0.1268
# Epoch 21/200
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9721 - loss: 0.0828
# Epoch 21: val_accuracy did not improve from 0.95972
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9721 - loss: 0.0827 - val_accuracy: 0.9408 - val_loss: 0.1760
# Epoch 22/200
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9658 - loss: 0.0881
# Epoch 22: val_accuracy did not improve from 0.95972
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9659 - loss: 0.0881 - val_accuracy: 0.9360 - val_loss: 0.1831
# Epoch 23/200
# 102/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9803 - loss: 0.0593
# Epoch 23: val_accuracy did not improve from 0.95972
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9803 - loss: 0.0591 - val_accuracy: 0.9479 - val_loss: 0.1682
# Epoch 24/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9824 - loss: 0.0503
# Epoch 24: val_accuracy did not improve from 0.95972
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9824 - loss: 0.0503 - val_accuracy: 0.9597 - val_loss: 0.1535
# Epoch 25/200
# 101/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9818 - loss: 0.0548
# Epoch 25: val_accuracy improved from 0.95972 to 0.96209, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9818 - loss: 0.0548 - val_accuracy: 0.9621 - val_loss: 0.1476
# Epoch 26/200
# 101/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9817 - loss: 0.0549
# Epoch 26: val_accuracy did not improve from 0.96209
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9814 - loss: 0.0554 - val_accuracy: 0.9408 - val_loss: 0.1727
# Epoch 27/200
# 105/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9796 - loss: 0.0605
# Epoch 27: val_accuracy did not improve from 0.96209
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9795 - loss: 0.0605 - val_accuracy: 0.9573 - val_loss: 0.1161
# Epoch 28/200
# 101/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9863 - loss: 0.0374
# Epoch 28: val_accuracy did not improve from 0.96209
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9863 - loss: 0.0379 - val_accuracy: 0.9573 - val_loss: 0.1251
# Epoch 29/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9859 - loss: 0.0384
# Epoch 29: val_accuracy did not improve from 0.96209
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9859 - loss: 0.0386 - val_accuracy: 0.9479 - val_loss: 0.1598
# Epoch 30/200
# 105/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9801 - loss: 0.0568
# Epoch 30: val_accuracy did not improve from 0.96209
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9801 - loss: 0.0567 - val_accuracy: 0.9384 - val_loss: 0.1615
# Epoch 31/200
# 102/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9804 - loss: 0.0479
# Epoch 31: val_accuracy did not improve from 0.96209
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9805 - loss: 0.0478 - val_accuracy: 0.9597 - val_loss: 0.1457
# Epoch 32/200
# 102/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9787 - loss: 0.0723
# Epoch 32: val_accuracy improved from 0.96209 to 0.97156, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9790 - loss: 0.0713 - val_accuracy: 0.9716 - val_loss: 0.1437
# Epoch 33/200
# 105/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9821 - loss: 0.0503
# Epoch 33: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9822 - loss: 0.0502 - val_accuracy: 0.9645 - val_loss: 0.1278
# Epoch 34/200
# 102/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9837 - loss: 0.0451
# Epoch 34: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9837 - loss: 0.0453 - val_accuracy: 0.9597 - val_loss: 0.1430
# Epoch 35/200
# 103/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9902 - loss: 0.0365
# Epoch 35: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9902 - loss: 0.0364 - val_accuracy: 0.9526 - val_loss: 0.1623
# Epoch 36/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9898 - loss: 0.0356
# Epoch 36: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9897 - loss: 0.0357 - val_accuracy: 0.9526 - val_loss: 0.1308
# Epoch 37/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9883 - loss: 0.0328
# Epoch 37: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9882 - loss: 0.0330 - val_accuracy: 0.9526 - val_loss: 0.1494
# Epoch 38/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9848 - loss: 0.0443
# Epoch 38: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9847 - loss: 0.0446 - val_accuracy: 0.9550 - val_loss: 0.1282
# Epoch 39/200
# 103/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9815 - loss: 0.0473
# Epoch 39: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9815 - loss: 0.0473 - val_accuracy: 0.9668 - val_loss: 0.1043
# Epoch 40/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9909 - loss: 0.0263
# Epoch 40: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9909 - loss: 0.0263 - val_accuracy: 0.9597 - val_loss: 0.1559
# Epoch 41/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9893 - loss: 0.0345
# Epoch 41: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9893 - loss: 0.0344 - val_accuracy: 0.9692 - val_loss: 0.1017
# Epoch 42/200
# 105/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9918 - loss: 0.0264
# Epoch 42: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9918 - loss: 0.0266 - val_accuracy: 0.9573 - val_loss: 0.1240
# Epoch 43/200
# 102/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9853 - loss: 0.0512
# Epoch 43: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9854 - loss: 0.0510 - val_accuracy: 0.9621 - val_loss: 0.1803
# Epoch 44/200
# 102/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9909 - loss: 0.0271
# Epoch 44: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9908 - loss: 0.0273 - val_accuracy: 0.9692 - val_loss: 0.1016
# Epoch 45/200
# 105/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9932 - loss: 0.0258
# Epoch 45: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9931 - loss: 0.0260 - val_accuracy: 0.9692 - val_loss: 0.1027
# Epoch 46/200
# 103/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9867 - loss: 0.0349
# Epoch 46: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9868 - loss: 0.0349 - val_accuracy: 0.9668 - val_loss: 0.0972
# Epoch 47/200
# 101/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9891 - loss: 0.0305
# Epoch 47: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9891 - loss: 0.0307 - val_accuracy: 0.9597 - val_loss: 0.1408
# Epoch 48/200
# 101/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9868 - loss: 0.0390
# Epoch 48: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9868 - loss: 0.0389 - val_accuracy: 0.9597 - val_loss: 0.1674
# Epoch 49/200
# 101/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9932 - loss: 0.0215
# Epoch 49: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9930 - loss: 0.0219 - val_accuracy: 0.9645 - val_loss: 0.1191
# Epoch 50/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9949 - loss: 0.0184
# Epoch 50: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9948 - loss: 0.0187 - val_accuracy: 0.9573 - val_loss: 0.1347
# Epoch 51/200
# 105/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9922 - loss: 0.0319
# Epoch 51: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9922 - loss: 0.0319 - val_accuracy: 0.9668 - val_loss: 0.1325
# Epoch 52/200
# 102/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9870 - loss: 0.0244
# Epoch 52: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9872 - loss: 0.0244 - val_accuracy: 0.9645 - val_loss: 0.1519
# Epoch 53/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9924 - loss: 0.0198
# Epoch 53: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9924 - loss: 0.0199 - val_accuracy: 0.9692 - val_loss: 0.1757
# Epoch 54/200
# 102/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9859 - loss: 0.0326
# Epoch 54: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9859 - loss: 0.0328 - val_accuracy: 0.9550 - val_loss: 0.1837
# Epoch 55/200
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9832 - loss: 0.0522
# Epoch 55: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9831 - loss: 0.0523 - val_accuracy: 0.9573 - val_loss: 0.1171
# Epoch 56/200
# 103/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9910 - loss: 0.0337
# Epoch 56: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9909 - loss: 0.0338 - val_accuracy: 0.9597 - val_loss: 0.1341
# Epoch 57/200
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9909 - loss: 0.0332
# Epoch 57: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9909 - loss: 0.0331 - val_accuracy: 0.9716 - val_loss: 0.0974
# Epoch 58/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9955 - loss: 0.0211
# Epoch 58: val_accuracy did not improve from 0.97156
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9954 - loss: 0.0215 - val_accuracy: 0.9621 - val_loss: 0.1181
# Epoch 59/200
# 103/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9892 - loss: 0.0375
# Epoch 59: val_accuracy improved from 0.97156 to 0.97393, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9892 - loss: 0.0373 - val_accuracy: 0.9739 - val_loss: 0.1001
# Epoch 60/200
# 103/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9934 - loss: 0.0198
# Epoch 60: val_accuracy did not improve from 0.97393
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9934 - loss: 0.0200 - val_accuracy: 0.9621 - val_loss: 0.1129
# Epoch 61/200
# 105/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9890 - loss: 0.0372
# Epoch 61: val_accuracy did not improve from 0.97393
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9890 - loss: 0.0372 - val_accuracy: 0.9645 - val_loss: 0.1342
# Epoch 62/200
# 105/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9888 - loss: 0.0311
# Epoch 62: val_accuracy did not improve from 0.97393
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9888 - loss: 0.0310 - val_accuracy: 0.9668 - val_loss: 0.1253
# Epoch 63/200
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9893 - loss: 0.0313
# Epoch 63: val_accuracy did not improve from 0.97393
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9893 - loss: 0.0313 - val_accuracy: 0.9621 - val_loss: 0.1298
# Epoch 64/200
# 105/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9931 - loss: 0.0181
# Epoch 64: val_accuracy improved from 0.97393 to 0.97867, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9932 - loss: 0.0181 - val_accuracy: 0.9787 - val_loss: 0.0978
# Epoch 65/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9933 - loss: 0.0161
# Epoch 65: val_accuracy did not improve from 0.97867
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9933 - loss: 0.0161 - val_accuracy: 0.9645 - val_loss: 0.1385
# Epoch 66/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9965 - loss: 0.0116
# Epoch 66: val_accuracy did not improve from 0.97867
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9965 - loss: 0.0116 - val_accuracy: 0.9692 - val_loss: 0.1283
# Epoch 67/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9965 - loss: 0.0142
# Epoch 67: val_accuracy did not improve from 0.97867
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9965 - loss: 0.0143 - val_accuracy: 0.9692 - val_loss: 0.1622
# Epoch 68/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9902 - loss: 0.0267
# Epoch 68: val_accuracy did not improve from 0.97867
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9902 - loss: 0.0267 - val_accuracy: 0.9621 - val_loss: 0.1761
# Epoch 69/200
# 102/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9876 - loss: 0.0306
# Epoch 69: val_accuracy improved from 0.97867 to 0.98341, saving model to /kaggle/working/paper_replication_model.h5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9875 - loss: 0.0310 - val_accuracy: 0.9834 - val_loss: 0.1064
# Epoch 70/200
# 104/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9854 - loss: 0.0378
# Epoch 70: val_accuracy did not improve from 0.98341
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9854 - loss: 0.0379 - val_accuracy: 0.9645 - val_loss: 0.1484
# Epoch 71/200
# 102/106 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9872 - loss: 0.0457
# Epoch 71: val_accuracy did not improve from 0.98341
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9871 - loss: 0.0457 - val_accuracy: 0.9763 - val_loss: 0.1195
# Epoch 71: early stopping
# Restoring model weights from the end of the best epoch: 46.

# %% [markdown]
# ### 8. Visualizing Training History and Final Evaluation
#
# After training is complete, it's essential to evaluate the model's performance. This cell performs two key tasks:
#
# 1.  **Plotting Learning Curves:** It visualizes the model's `accuracy` and `loss` for both the training and validation sets over each epoch. This helps us understand if the model learned effectively and whether it overfit the training data.
# 2.  **Final Test Evaluation:** It loads the best model saved by `ModelCheckpoint` and evaluates its performance on the **unseen test set**. This provides the final, unbiased measure of the model's accuracy.

# %%
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    plt.figure(figsize=(14, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'bo-', label='Training acc')
    plt.plot(epochs, val_acc, 'ro-', label='Validation acc')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.grid(True)
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'bo-', label='Training loss')
    plt.plot(epochs, val_loss, 'ro-', label='Validation loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.grid(True)
    plt.legend()
    
    plt.show()

plot_history(history)


print("Loading the best model saved during training...")
best_model = load_model(os.path.join(WORKING_DIR, 'paper_replication_model.h5'))

print("\nEvaluating model on the test set...")
test_loss, test_acc = best_model.evaluate(test_generator, verbose=1)
print(f'\nFinal Test Accuracy: {test_acc:.4f}')
print(f'Final Test Loss: {test_loss:.4f}')
# Out:
# Loading the best model saved during training...
#
# Evaluating model on the test set...
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.9708 - loss: 0.1278
#
# Final Test Accuracy: 0.9621
# Final Test Loss: 0.1938

# %% [markdown]
# ### 9. In-Depth Performance Analysis
#
# To get a more granular understanding of the model's behavior, we generate two key reports:
#
# - **Classification Report:** This provides class-wise metrics, including:
#     - **Precision:** Of all the times the model predicted a certain class, how often was it correct?
#     - **Recall:** Of all the actual instances of a class, how many did the model correctly identify?
#     - **F1-Score:** The harmonic mean of precision and recall, providing a single score for a class's performance.
#
# - **Confusion Matrix:** This is a powerful visualization that shows exactly where the model is making mistakes. The diagonal represents correct predictions, while off-diagonal cells show which classes are being confused with one another.

# %%
y_pred_probs = best_model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_generator.classes

class_labels = sorted(test_generator.class_indices.keys())


print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_labels))


print("\nConfusion Matrix:\n")
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
#
# Classification Report:
#
#                 precision    recall  f1-score   support
#
#   sal_data_100       0.95      0.98      0.97       106
#    sal_data_50       0.96      0.94      0.95       105
#    sal_data_80       0.96      0.99      0.98       106
# sal_data_empty       0.97      0.93      0.95       105
#
#       accuracy                           0.96       422
#      macro avg       0.96      0.96      0.96       422
#   weighted avg       0.96      0.96      0.96       422
#
#
# Confusion Matrix:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np


y_pred_probs = best_model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_generator.classes
class_labels = sorted(test_generator.class_indices.keys())


fig = plt.figure(figsize=(20, 12))


plt.subplot(2, 3, 1)
cm_normalized = confusion_matrix(y_true, y_pred, normalize='true')
sns.heatmap(cm_normalized, annot=True, fmt='.2%', cmap='Blues', 
            xticklabels=class_labels, yticklabels=class_labels)
plt.title('Normalized Confusion Matrix (by Row/True Label)', fontsize=12, fontweight='bold')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')


plt.subplot(2, 3, 2)
class_accuracies = cm_normalized.diagonal()
colors = ['#2ecc71' if acc >= 0.95 else '#f39c12' if acc >= 0.90 else '#e74c3c' 
          for acc in class_accuracies]
bars = plt.bar(range(len(class_labels)), class_accuracies, color=colors, alpha=0.7)
plt.xticks(range(len(class_labels)), class_labels, rotation=45, ha='right')
plt.ylabel('Accuracy')
plt.title('Per-Class Accuracy', fontsize=12, fontweight='bold')
plt.ylim([0, 1.05])
plt.axhline(y=0.90, color='r', linestyle='--', alpha=0.3, label='90% threshold')
plt.axhline(y=0.95, color='g', linestyle='--', alpha=0.3, label='95% threshold')
plt.legend()
plt.grid(axis='y', alpha=0.3)

for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.2%}', ha='center', va='bottom', fontsize=9)


plt.subplot(2, 3, 3)
report_dict = classification_report(y_true, y_pred, target_names=class_labels, output_dict=True)
metrics = ['precision', 'recall', 'f1-score']
x = np.arange(len(class_labels))
width = 0.25

for i, metric in enumerate(metrics):
    values = [report_dict[label][metric] for label in class_labels]
    plt.bar(x + i*width, values, width, label=metric.capitalize(), alpha=0.8)

plt.xlabel('Class')
plt.ylabel('Score')
plt.title('Precision, Recall, F1-Score per Class', fontsize=12, fontweight='bold')
plt.xticks(x + width, class_labels, rotation=45, ha='right')
plt.ylim([0, 1.05])
plt.legend()
plt.grid(axis='y', alpha=0.3)


plt.subplot(2, 3, 4)
max_probs = np.max(y_pred_probs, axis=1)
correct_mask = (y_pred == y_true)
plt.hist(max_probs[correct_mask], bins=30, alpha=0.7, label='Correct', color='green', edgecolor='black')
plt.hist(max_probs[~correct_mask], bins=30, alpha=0.7, label='Incorrect', color='red', edgecolor='black')
plt.xlabel('Prediction Confidence')
plt.ylabel('Frequency')
plt.title('Prediction Confidence Distribution', fontsize=12, fontweight='bold')
plt.legend()
plt.grid(axis='y', alpha=0.3)


from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

plt.subplot(2, 3, 5)
y_true_bin = label_binarize(y_true, classes=range(len(class_labels)))
colors = ['#e74c3c', '#3498db', '#2ecc71', '#f39c12']

for i, (label, color) in enumerate(zip(class_labels, colors)):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=color, lw=2, 
             label=f'{label} (AUC = {roc_auc:.3f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random Classifier')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves (One-vs-Rest)', fontsize=12, fontweight='bold')
plt.legend(loc="lower right", fontsize=8)
plt.grid(alpha=0.3)


plt.subplot(2, 3, 6)
cm_abs = confusion_matrix(y_true, y_pred)
errors_per_class = []
for i in range(len(class_labels)):
    total_errors = cm_abs[i].sum() - cm_abs[i, i]
    errors_per_class.append(total_errors)

bars = plt.bar(range(len(class_labels)), errors_per_class, 
               color=['#e74c3c' if e > 5 else '#f39c12' if e > 2 else '#2ecc71' for e in errors_per_class],
               alpha=0.7)
plt.xticks(range(len(class_labels)), class_labels, rotation=45, ha='right')
plt.ylabel('Number of Errors')
plt.title('Total Misclassifications per Class', fontsize=12, fontweight='bold')
plt.grid(axis='y', alpha=0.3)

for bar, error in zip(bars, errors_per_class):
    plt.text(bar.get_x() + bar.get_width()/2., bar.get_height(),
             f'{int(error)}', ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()


print("\n" + "="*60)
print("DETAILED PERFORMANCE SUMMARY")
print("="*60)
print(f"\nOverall Test Accuracy: {test_acc:.4f} ({test_acc*100:.2f}%)")
print(f"Overall Test Loss: {test_loss:.4f}")
print(f"\nMean Prediction Confidence (Correct): {max_probs[correct_mask].mean():.4f}")
print(f"Mean Prediction Confidence (Incorrect): {max_probs[~correct_mask].mean():.4f}")
print(f"\nTotal Correct Predictions: {correct_mask.sum()}/{len(y_true)}")
print(f"Total Incorrect Predictions: {(~correct_mask).sum()}/{len(y_true)}")

print("\n" + "-"*60)
print("PER-CLASS METRICS")
print("-"*60)
for i, label in enumerate(class_labels):
    print(f"\n{label}:")
    print(f"  Accuracy: {class_accuracies[i]:.4f} ({class_accuracies[i]*100:.2f}%)")
    print(f"  Precision: {report_dict[label]['precision']:.4f}")
    print(f"  Recall: {report_dict[label]['recall']:.4f}")
    print(f"  F1-Score: {report_dict[label]['f1-score']:.4f}")
    print(f"  Support: {int(report_dict[label]['support'])}")
    print(f"  Errors: {errors_per_class[i]}")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# ============================================================
# DETAILED PERFORMANCE SUMMARY
# ============================================================
#
# Overall Test Accuracy: 0.9621 (96.21%)
# Overall Test Loss: 0.1938
#
# Mean Prediction Confidence (Correct): 0.9895
# Mean Prediction Confidence (Incorrect): 0.8569
#
# Total Correct Predictions: 406/422
# Total Incorrect Predictions: 16/422
#
# ------------------------------------------------------------
# PER-CLASS METRICS
# ------------------------------------------------------------
#
# sal_data_100:
#   Accuracy: 0.9811 (98.11%)
#   Precision: 0.9541
#   Recall: 0.9811
#   F1-Score: 0.9674
#   Support: 106
#   Errors: 2
#
# sal_data_50:
#   Accuracy: 0.9429 (94.29%)
#   Precision: 0.9612
#   Recall: 0.9429
#   F1-Score: 0.9519
#   Support: 105
#   Errors: 6
#
# sal_data_80:
#   Accuracy: 0.9906 (99.06%)
#   Precision: 0.9633
#   Recall: 0.9906
#   F1-Score: 0.9767
#   Support: 106
#   Errors: 1
#
# sal_data_empty:
#   Accuracy: 0.9333 (93.33%)
#   Precision: 0.9703
#   Recall: 0.9333
#   F1-Score: 0.9515
#   Support: 105
#   Errors: 7

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc




OUT_DIR = "/kaggle/working"
os.makedirs(OUT_DIR, exist_ok=True)






epochs = range(1, len(history.history["accuracy"]) + 1)

plt.figure(figsize=(14, 5))


plt.subplot(1, 2, 1)
plt.plot(epochs, history.history["accuracy"], "bo-", label="Training acc")
plt.plot(epochs, history.history["val_accuracy"], "ro-", label="Validation acc")
plt.title("Training and Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.ylim(0, 1.05)
plt.legend()
plt.grid(alpha=0.3)


plt.subplot(1, 2, 2)
plt.plot(epochs, history.history["loss"], "bo-", label="Training loss")
plt.plot(epochs, history.history["val_loss"], "ro-", label="Validation loss")
plt.title("Training and Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(OUT_DIR, "accuracy_loss_over_epochs.png"))
plt.show()
plt.close()




y_pred_probs = best_model.predict(test_generator)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = test_generator.classes
class_labels = sorted(test_generator.class_indices.keys())


cm_norm = confusion_matrix(y_true, y_pred, normalize="true")
cm_abs = confusion_matrix(y_true, y_pred)


report_dict = classification_report(
    y_true, y_pred, target_names=class_labels, output_dict=True
)




plt.figure(figsize=(8, 6))
sns.heatmap(
    cm_norm,
    annot=True,
    fmt=".2f",           
    cmap="Blues",
    xticklabels=class_labels,
    yticklabels=class_labels,
)
plt.title("Normalized Confusion Matrix (by Row/True Label)", fontsize=12, fontweight="bold")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.tight_layout()
plt.savefig(os.path.join(OUT_DIR, "confusion_matrix_normalized.png"))
plt.show()
plt.close()




plt.figure(figsize=(8, 6))
class_accuracies = cm_norm.diagonal()
colors = [
    "#2ecc71" if acc >= 0.95 else "#f39c12" if acc >= 0.90 else "#e74c3c"
    for acc in class_accuracies
]
bars = plt.bar(range(len(class_labels)), class_accuracies, color=colors, alpha=0.7)
plt.xticks(range(len(class_labels)), class_labels, rotation=45, ha="right")
plt.ylabel("Accuracy")
plt.title("Per-Class Accuracy", fontsize=12, fontweight="bold")
plt.ylim([0, 1.05])
plt.axhline(y=0.90, color="r", linestyle="--", alpha=0.3, label="90% threshold")
plt.axhline(y=0.95, color="g", linestyle="--", alpha=0.3, label="95% threshold")
plt.legend()
plt.grid(axis="y", alpha=0.3)
for bar in bars:
    h = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2.0, h, f"{h:.2f}", ha="center", va="bottom", fontsize=9)
plt.tight_layout()
plt.savefig(os.path.join(OUT_DIR, "per_class_accuracy.png"))
plt.show()
plt.close()




plt.figure(figsize=(10, 6))
metrics = ["precision", "recall", "f1-score"]
x = np.arange(len(class_labels))
width = 0.25

for i, metric in enumerate(metrics):
    values = [report_dict[label][metric] for label in class_labels]
    plt.bar(x + i * width, values, width, label=metric.capitalize(), alpha=0.8)

plt.xlabel("Class")
plt.ylabel("Score")
plt.title("Precision, Recall, F1-Score per Class", fontsize=12, fontweight="bold")
plt.xticks(x + width, class_labels, rotation=45, ha="right")
plt.ylim([0, 1.05])
plt.legend()
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(OUT_DIR, "per_class_prf_bar.png"))
plt.show()
plt.close()




plt.figure(figsize=(8, 6))
max_probs = np.max(y_pred_probs, axis=1)
correct_mask = y_pred == y_true
plt.hist(
    max_probs[correct_mask],
    bins=30,
    alpha=0.7,
    label="Correct",
    color="green",
    edgecolor="black",
)
plt.hist(
    max_probs[~correct_mask],
    bins=30,
    alpha=0.7,
    label="Incorrect",
    color="red",
    edgecolor="black",
)
plt.xlabel("Prediction Confidence")
plt.ylabel("Frequency")
plt.title("Prediction Confidence Distribution", fontsize=12, fontweight="bold")
plt.legend()
plt.grid(axis="y", alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(OUT_DIR, "prediction_confidence_distribution.png"))
plt.show()
plt.close()




plt.figure(figsize=(8, 6))
y_true_bin = label_binarize(y_true, classes=range(len(class_labels)))

base_colors = ["#e74c3c", "#3498db", "#2ecc71", "#f39c12", "#9b59b6", "#1abc9c", "#34495e"]
colors = (base_colors * ((len(class_labels) // len(base_colors)) + 1))[: len(class_labels)]

for i, (label, color) in enumerate(zip(class_labels, colors)):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_pred_probs[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=color, lw=2, label=f"{label} (AUC = {roc_auc:.3f})")

plt.plot([0, 1], [0, 1], "k--", lw=2, label="Random Classifier")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curves (One-vs-Rest)", fontsize=12, fontweight="bold")
plt.legend(loc="lower right", fontsize=8)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig(os.path.join(OUT_DIR, "roc_curves_ovr.png"))
plt.show()
plt.close()




plt.figure(figsize=(8, 6))
errors_per_class = []
for i in range(len(class_labels)):
    total_errors = cm_abs[i].sum() - cm_abs[i, i]
    errors_per_class.append(total_errors)

bars = plt.bar(
    range(len(class_labels)),
    errors_per_class,
    color=["#e74c3c" if e > 5 else "#f39c12" if e > 2 else "#2ecc71" for e in errors_per_class],
    alpha=0.7,
)
plt.xticks(range(len(class_labels)), class_labels, rotation=45, ha="right")
plt.ylabel("Number of Errors")
plt.title("Total Misclassifications per Class", fontsize=12, fontweight="bold")
plt.grid(axis="y", alpha=0.3)
for bar, error in zip(bars, errors_per_class):
    plt.text(bar.get_x() + bar.get_width() / 2.0, bar.get_height(), f"{int(error)}",
             ha="center", va="bottom", fontsize=10)
plt.tight_layout()
plt.savefig(os.path.join(OUT_DIR, "classwise_errors.png"))
plt.show()
plt.close()




print("\n" + "=" * 60)
print("DETAILED PERFORMANCE SUMMARY")
print("=" * 60)
print(f"\nOverall Test Accuracy: {test_acc:.4f} ({test_acc*100:.2f}%)")
print(f"Overall Test Loss: {test_loss:.4f}")
print(f"\nMean Prediction Confidence (Correct): {max_probs[correct_mask].mean():.4f}")
print(f"Mean Prediction Confidence (Incorrect): {max_probs[~correct_mask].mean():.4f}")
print(f"\nTotal Correct Predictions: {correct_mask.sum()}/{len(y_true)}")
print(f"Total Incorrect Predictions: {(~correct_mask).sum()}/{len(y_true)}")

print("\n" + "-" * 60)
print("PER-CLASS METRICS")
print("-" * 60)
for i, label in enumerate(class_labels):
    print(f"\n{label}:")
    print(f"  Accuracy: {class_accuracies[i]:.4f} ({class_accuracies[i]*100:.2f}%)")
    print(f"  Precision: {report_dict[label]['precision']:.4f}")
    print(f"  Recall: {report_dict[label]['recall']:.4f}")
    print(f"  F1-Score: {report_dict[label]['f1-score']:.4f}")
    print(f"  Support: {int(report_dict[label]['support'])}")
    print(f"  Errors: {errors_per_class[i]}")
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# ============================================================
# DETAILED PERFORMANCE SUMMARY
# ============================================================
#
# Overall Test Accuracy: 0.9621 (96.21%)
# Overall Test Loss: 0.1938
#
# Mean Prediction Confidence (Correct): 0.9895
# Mean Prediction Confidence (Incorrect): 0.8569
#
# Total Correct Predictions: 406/422
# Total Incorrect Predictions: 16/422
#
# ------------------------------------------------------------
# PER-CLASS METRICS
# ------------------------------------------------------------
#
# sal_data_100:
#   Accuracy: 0.9811 (98.11%)
#   Precision: 0.9541
#   Recall: 0.9811
#   F1-Score: 0.9674
#   Support: 106
#   Errors: 2
#
# sal_data_50:
#   Accuracy: 0.9429 (94.29%)
#   Precision: 0.9612
#   Recall: 0.9429
#   F1-Score: 0.9519
#   Support: 105
#   Errors: 6
#
# sal_data_80:
#   Accuracy: 0.9906 (99.06%)
#   Precision: 0.9633
#   Recall: 0.9906
#   F1-Score: 0.9767
#   Support: 106
#   Errors: 1
#
# sal_data_empty:
#   Accuracy: 0.9333 (93.33%)
#   Precision: 0.9703
#   Recall: 0.9333
#   F1-Score: 0.9515
#   Support: 105
#   Errors: 7
